# %% [markdown]
# # <font color='grey'><center> Hubert10 😎</center></font>
#
# # <font color='grey'><center> Time Series </center></font>

# %% [markdown]
# # <font color='grey'>Spis treści </font>
#
# ### <font color='orange'> Wstęp – przykłady szeregów czasowych </font>
# - Wykres notowań kursu euro
# - Prawo Moore'a
# - Ranking najlepszych procesorów
# - Warszawska Wyższa Szkoła Informatyki - WYKŁAD INAUGURACYJNY 2015 / 2016
#
# ### <font color='green'> Python w analizie danych  </font>
# - 11. Szeregi czasowe (301)
# - 11.1. Typy danych i narzędzia przeznaczone do obsługi daty i czasu (302)
# - Konwersja pomiędzy obiektami string i datetime (303)
#     - datetime -> string
#         - funkcja str()
#         - metoda strftime()
#     - string -> datetime
#     - funkcja strptime
#     - metoda parser.parse
#     - metoda to_datetime
#
#
# ###  <font color='red'> U.S. Gasoline and Diesel Retail Prices 1995-2021 </font>
# - Statystyka
# - Typy danych i zmiana indeksu
# - Dodanie kolumn
# - Wykres 1995-2021r
# - Wykres 2020r.
# - 4 Wykresy (można wyświetlać 'dane.A1' albo 'wykres20.A1')
# - Próbkowanie ziarnistości

# %% [markdown]
# # <font color='orange'><center> Wstęp – przykłady szeregów czasowych </center></font>

# %% [markdown]
# Wiele szeregów czasowych charakteryzuje się **stałą częstotliwością** (poszczególne obserwacje są rejestrowane w równych odstępach czasu np. co 15 sekund).
#
# Szeregi czasowe <font color='red'>mogą</font> charakteryzowac się też **zmienną częstotliwością** rejestrowania obserwacji.

# %% [markdown]
# ### <font color='orange'><center> Wykres notowań kursu euro </center></font>
#
#
# ![image.png](attachment:image.png)
#
# https://www.walutomat.pl/kursy-walut/eur-pln/

# %% [markdown]
# ### <font color='orange'><center> Prawo Moore'a  </center></font>
#
# **Prawo Moore'a** - gęstość upakowania tranzystorów na cal kwadratowy procesora podwaja się co dwa lata
#
# ![image.png](attachment:image.png)
#
# "... **obecnie liczba tranzystorów w procesorach ogólnego przeznaczenia wzrasta o 50 procent w skali roku, przy zaledwie 10 procentowej poprawie wydajności tych układów.** Jednak argumentacja opierająca się na wydajności nie obala prawa Moore’a, które nic nie mówi o tym aspekcie, a dotyczy jedynie podwajania liczby tranzystorów."
# https://www.chip.pl/2017/10/szef-nvidii-koniec-prawa-moorea/ [4 października 2017]

# %%
# podwaja się co dwa lata

import math

pierwiastek2 = math.sqrt(2)
print('Pierwiastek z 2 =',pierwiastek2)

poroku = 100 * pierwiastek2
print("\nporoku:", poroku)

za2lata = poroku * pierwiastek2
print("\nza 2 lata:", za2lata)
# Out:
# Pierwiastek z 2 = 1.4142135623730951
#
# poroku: 141.4213562373095
#
# za 2 lata: 200.00000000000003

# %%
# jeśli podwaja się co 2 lata to wzrastało o 41% w skali roku

za10latco41 = 100 * pierwiastek2**10
za10latco41
# Out:
# 3200.0000000000023

# %%
# obecnie wzrasta o 50% w skali roku

za10latco50 = 100 * 1.50**10
za10latco50
# Out:
# 5766.50390625

# %%
wydajnosc = 100 * 1.10**10
wydajnosc # wzrost wydajności po 10 latach
# Out:
# 259.3742460100002

# %%
wydajnosc = 100 * 1.10**2
wydajnosc # wzrost wydajności po 2 latach
# Out:
# 121.00000000000001

# %% [markdown]
# #### https://mfiles.pl/pl/index.php/Prawo_Moore%27a
#
# #### http://zeszyty-naukowe.wwsi.edu.pl/zeszyty/zeszyt13/Ontologia_cyberprzestrzeni.pdf
# "tzw. prawo Moore’a, które na podstawie danych empirycznych, prowadziło
# do wniosków, że co 18 miesięcy podwaja się liczba tranzystorów w układzie
# scalonym (sformułowana tak w roku 1965 zależność w dziesięć lat później
# była aktualizowane – co 2 lata, **a w roku 1999 Moore uznał, że dotąd podwajanie będzie następować co 4-5 lat)**;"

# %% [markdown]
# ### <font color='orange'><center> Ranking najlepszych procesorów   </center></font>
#
# https://www.cpubenchmark.net/cpu_list.php
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### <font color='orange'><center> Warszawska Wyższa Szkoła Informatyki - WYKŁAD INAUGURACYJNY 2015 / 2016   </center></font>
#
# - https://www.youtube.com/watch?v=jp_SOBuOsi0&ab_channel=Ma%C5%82achMa%C5%82achOficjalnykana%C5%82wykonawcy

# %% [markdown]
# 10:50
# ![image.png](attachment:image.png)

# %% [markdown]
# 12:40
# ![image.png](attachment:image.png)

# %% [markdown]
# 15:00
# ![image.png](attachment:image.png)

# %% [markdown]
# 14:35
# ![image.png](attachment:image.png)

# %% [markdown]
# # <font color='green'><center> Python w analizie danych </center></font>
# ![image.png](attachment:image.png)
# <center> Data wydania książki: 2018-06-15 </center>

# %% [markdown]
# ### Wes McKinney (autor ksiażki) jest autorem biblioteki Pandas w Python
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 11. Szeregi czasowe (301)
#
# - 11.1. Typy danych i narzędzia przeznaczone do obsługi daty i czasu (302)
#     - Konwersja pomiędzy obiektami string i datetime (303)
# - 11.2. Podstawy szeregów czasowych (305)
#     - Indeksowanie i wybieranie (306)
#     - Szeregi czasowe z duplikatami indeksów (309)
# - 11.3. Zakresy dat, częstotliwości i przesunięcia (310)
#     - Generowanie zakresów dat (310)
#     - Częstotliwości i przesunięcia daty (313)
#     - Przesuwanie daty (314)
# - 11.4. Obsługa strefy czasowej (317)
#     - Lokalizacja i konwersja stref czasowych (317)
#     - Operacje z udziałem obiektów Timestamp o wyznaczonej strefie czasowej (319)
#     - Operacje pomiędzy różnymi strefami czasowymi (320)
# - 11.5. Okresy i przeprowadzanie na nich operacji matematycznych (321)
#     - Konwersja częstotliwości łańcuchów (322)
#     - Kwartalne częstotliwości okresów (323)
#     - Konwersja znaczników czasu na okresy (i z powrotem) (325)
#     - Tworzenie obiektów PeriodIndex na podstawie tablic (326)
# - 11.6. Zmiana rozdzielczości i konwersja częstotliwości (328)
#     - Zmniejszanie częstotliwości (329)
#     - Zwiększanie rozdzielczości i interpolacja (332)
#     - Zmiana rozdzielczości z okresami (333)
# - 11.7. Funkcje ruchomego okna (334)
#     - Funkcje ważone wykładniczo (337)
#     - Binarne funkcje ruchomego okna (338)
#     - Funkcje ruchomego okna definiowane przez użytkownika (340)
# - 11.8. Podsumowanie (340)

# %% [markdown]
# # Wersja Python

# %%
# $ PYTHON

# Autor książki korzysta z wersji Python 3.6.0

# %%
# Moja wersja Python
from platform import python_version

python_version()
# Out:
# '3.8.3'

# %% [markdown]
# # <font color='green'><center> 11. Szeregi czasowe (301) </center></font>

# %% [markdown]
# ### Pracując z szeregami czasowymi można spotkać:
# - **Znaczniki czasu** - określają czas dokonania obserwacji.
# - Stałe **okresy**, takie jak miesiąc (np. styczeń 2007) lub cały rok (np. 2010).
# - **Interwały** oznaczone znacznikiem czasu rozpoczęcia i znacznikiem czasu zakończenia.
#     - (okresy mozna traktować jako charakterystyczne interwały)
# - Szereg czasowy eksperymentu, gdzie każdy znacznik czasu określa czas, który upłynał od określonego momentu (szeregi czasowe mogą np. podawać średnicę pieczonego ciastka w zależności od czasu jego pieczenia).

# %% [markdown]
# #  <font color='green'><center> 11.1. Typy danych i narzędzia przeznaczone do obsługi daty i czasu (302) </center></font>

# %%
# Najczęściej stosowany typ danych czasowych to *datetime.datetime* lub po prostu *datetime*

from datetime import datetime

teraz = datetime.now()
teraz
# Out:
# datetime.datetime(2021, 6, 2, 21, 24, 59, 263058)

# %%
print('Rok:',teraz.year,
      '\nmiesiac:',teraz.month,
      '\ndzień:', teraz.day,
      '\ngodzina', teraz.hour,
      '\nminuta:', teraz.minute,
      '\nsekunda:', teraz.second,
      '\nmikrosekunda:', teraz.microsecond)
# Out:
# Rok: 2021
# miesiac: 6
# dzień: 2
# godzina 21
# minuta: 24
# sekunda: 59
# mikrosekunda: 263058

# %%
teraz.date()
# Out:
# datetime.date(2021, 6, 2)

# %%
teraz.time()
# Out:
# datetime.time(21, 24, 59, 263058)

# %%
roznica = teraz - datetime(2018, 10, 1) 

print('Jestem studentem WWSI',roznica.days,'dni')
# Out:
# Jestem studentem WWSI 975 dni

# %%
# KOMENTARZ day, days
# porównanie do int i float

z = 5-2 # mogę - + *
print(z)
# Out:
# 3

# %%
z = 5/2 
print(z)
# Out:
# 2.5

# %%
# x to typ *datatime.timedelta* lub po prostu *timedelta*
# timedelta = datetime - datetime

roznica
# Out:
# datetime.timedelta(days=975, seconds=77099, microseconds=263058)

# %%
# timedelta przedstawia różnicę pomiędzy dwoma datami

from datetime import timedelta

jutro = teraz + timedelta(1)
print(jutro)
# Out:
# 2021-06-03 21:24:59.263058

# %%
wczoraj = teraz - timedelta(1)
print(wczoraj)
# Out:
# 2021-06-01 21:24:59.263058

# %%
zarok = teraz + timedelta(365)
print(zarok)
# Out:
# 2022-06-02 21:24:59.263058

# %%
# Przykłady lat przestępnych: 2016, 2020, 2024, 2028 czy 2032

za10lat = teraz + 10 * timedelta(365) + timedelta(2)
print(za10lat)
# Out:
# 2031-06-02 21:24:59.263058

# %% [markdown]
# #### Tabela 11.1 Typy danych obsługiwane przez moduł datetime
# Typ danych - opis
# - date - rok, miesiąc, dzień
# - time - godzina, minuta, <font color='red'>sekunda</font>, mikrosekunda
# - datetime - rok, miesiąc, dzień, godzina, minuta, sekunda, mikrosekunda
# - timedelta - różnica pomiędzy dwoma wartościami datetime (w postaci dni, **sekund**, mikrosekund)
#
# *** tzinfo - przeznaczony do strefy czasowej

# %%
print(teraz)
# Out:
# 2021-06-02 21:24:59.263058

# %% [markdown]
# 3.5 h = 3.5 * 60 * 60 = 12 600 s

# %%
za3ipolh = teraz + timedelta(0,12600,0)
print(za3ipolh)
# Out:
# 2021-06-03 00:54:59.263058

# %% [markdown]
# ###  <font color='green'><center> Konwersja pomiędzy obiektami string i datetime (303) </center></font>

# %% [markdown]
# ###  <font color='green'><center> funkcja str() </center></font>  datetime -> string

# %%
datetime(2018,10,1)
# Out:
# datetime.datetime(2018, 10, 1, 0, 0)

# %%
data1 = datetime(2018, 10, 1)
str(data1) # funkcja str()
# Out:
# '2018-10-01 00:00:00'

# %%
x = str(data1)
print(type(x))
# Out:
# <class 'str'>

# %%
x
# Out:
# '2018-10-01 00:00:00'

# %% [markdown]
# ###  <font color='green'><center> metoda strftime() </center></font> datetime -> string

# %%
datetime(2018, 10, 1)
# Out:
# datetime.datetime(2018, 10, 1, 0, 0)

# %%
data2 = datetime(2018, 10, 1)
data2.strftime('%Y-%m-%d') # metoda strftime
# Out:
# '2018-10-01'

# %%
y = data2.strftime('%Y-%m-%d') # skrót '%F'
print(type(y))
# Out:
# <class 'str'>

# %%
y
# Out:
# '2018-10-01'

# %% [markdown]
# #### Tabela 11.2 Specyfikatory formatu daty i czasu (kompatybilne z ISO C89)

# %%
data3 = datetime(2018, 10, 1)

# %%
# wartość całkowitoliczbowa określająca dzień tygodnia [0 (niedziela), 6 (sobota)]

z = data3.strftime('%w')

# %%
print(type(z))
# Out:
# <class 'str'>

# %%
z
# Out:
# '1'

# %% [markdown]
# ###  <font color='green'><center> funkcja strptime </center></font> string -> datetime

# %%
value = '2018-10-1'
datetime.strptime(value, '%Y-%m-%d')
# Out:
# datetime.datetime(2018, 10, 1, 0, 0)

# %%
datestrs = ['2/10/2018','3/10/2018', '5/10/2018']
[datetime.strptime(daty, '%d/%m/%Y') for daty in datestrs]
# Out:
# [datetime.datetime(2018, 10, 2, 0, 0),
#  datetime.datetime(2018, 10, 3, 0, 0),
#  datetime.datetime(2018, 10, 5, 0, 0)]

# %% [markdown]
# ###  <font color='green'><center> metoda parser.parse </center></font> string -> datetime

# %%
from dateutil.parser import parse

parse('2018-10-1')
# Out:
# datetime.datetime(2018, 10, 1, 0, 0)

# %%
parse('Jan 31, 1997, 10:45 PM') # "Jan" można zmienić na 1
# Out:
# datetime.datetime(1997, 1, 31, 22, 45)

# %%
# dzień przed miesiącem

parse('6/12/2011', dayfirst=True)
# Out:
# datetime.datetime(2011, 12, 6, 0, 0)

# %% [markdown]
# ###  <font color='green'><center> metoda to_datetime </center></font> string -> datetime

# %%
import pandas as pd

daty2 = ['2011-07-06 12:00:00', '2011-08-06 12:00:00']
pd.to_datetime(daty2)
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 12:00:00'], dtype='datetime64[ns]', freq=None)

# %%
daty2 # daty nie zmieniły się na DatetimeIndex, bo nie przypisałem do zmiennej
# Out:
# ['2011-07-06 12:00:00', '2011-08-06 12:00:00']

# %%
idx = pd.to_datetime(daty2 + [None])
idx
# Out:
# DatetimeIndex(['2011-07-06 12:00:00', '2011-08-06 12:00:00', 'NaT'], dtype='datetime64[ns]', freq=None)

# %%
idx[2]
# Out:
# NaT

# %%
pd.isnull(idx)
# Out:
# array([False, False,  True])

# %% [markdown]
# **Wartością typu null stosowana przez pakiet pandas w danych znacznika czasu jest 'NaT' (z ang. Not a Time)**
#  - 'Nan'= Not a Number

# %% [markdown]
# #  <font color='red'><center> U.S. Gasoline and Diesel Retail Prices 1995-2021 </center></font>
#
# źródło danych: https://www.kaggle.com/mruanova/us-gasoline-and-diesel-retail-prices-19952021

# %%
import numpy as np
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
dane=pd.read_csv('C:\\Users\\V6\Desktop\\Gasoline.csv')                
dane
# Out:
#             Date     A1     A2     A3     R1     R2     R3     M1     M2  \
# 0     01/02/1995  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159
# 1     01/09/1995  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164
# 2     01/16/1995  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155
# 3     01/23/1995  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165
# 4     01/30/1995  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# 1356  12/28/2020  2.330  2.225  2.535  2.243  2.158  2.423  2.634  2.482
# 1357  01/04/2021  2.336  2.227  2.549  2.249  2.160  2.437  2.639  2.484
# 1358  01/11/2021  2.403  2.298  2.610  2.317  2.232  2.498  2.702  2.550
# 1359  01/18/2021  2.464  2.351  2.688  2.379  2.285  2.579  2.759  2.601
# 1360  01/25/2021  2.478  2.363  2.703  2.392  2.298  2.593  2.776  2.615
#
#          M3     P1     P2     P3     D1
# 0     1.298  1.272  1.250  1.386  1.104
# ...

# %% [markdown]
#     - A1: Weekly U.S. All Grades All Formulations Retail Gasoline Prices (Dollars per Gallon)
#     - A2: Weekly U.S. All Grades Conventional Retail Gasoline Prices (Dollars per Gallon)
#     - A3: Weekly U.S. All Grades Reformulated Retail Gasoline Prices (Dollars per Gallon)
#
#     - R1: Weekly U.S. Regular All Formulations Retail Gasoline Prices (Dollars per Gallon)
#     - R2: Weekly U.S. Regular Conventional Retail Gasoline Prices (Dollars per Gallon)
#     - R3: Weekly U.S. Regular Reformulated Retail Gasoline Prices (Dollars per Gallon)
#
#     - M1: Weekly U.S. Midgrade All Formulations Retail Gasoline Prices (Dollars per Gallon)
#     - M2: Weekly U.S. Midgrade Conventional Retail Gasoline Prices (Dollars per Gallon)
#     - M3: Weekly U.S. Midgrade Reformulated Retail Gasoline Prices (Dollars per Gallon)
#
#     - P1: Weekly U.S. Premium All Formulations Retail Gasoline Prices (Dollars per Gallon)
#     - P2: Weekly U.S. Premium Conventional Retail Gasoline Prices (Dollars per Gallon)
#     - P3: Weekly U.S. Premium Reformulated Retail Gasoline Prices (Dollars per Gallon)
#
#     - D1: Weekly U.S. No 2 Diesel Retail Prices (Dollars per Gallon)

# %%
# sprawdzenie NaN
dane.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ###  <font color='red'><center> Statystyka

# %%
dane.describe().style.format("{:.2f}")
# Out:
# <style  type="text/css" >
# </style><table id="T_3b08ec49_c3d8_11eb_9411_303a64f88675" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >A1</th>        <th class="col_heading level0 col1" >A2</th>        <th class="col_heading level0 col2" >A3</th>        <th class="col_heading level0 col3" >R1</th>        <th class="col_heading level0 col4" >R2</th>        <th class="col_heading level0 col5" >R3</th>        <th class="col_heading level0 col6" >M1</th>        <th class="col_heading level0 col7" >M2</th>        <th class="col_heading level0 col8" >M3</th>        <th class="col_heading level0 col9" >P1</th>        <th class="col_heading level0 col10" >P2</th>        <th class="col_heading level0 col11" >P3</th>        <th class="col_heading level0 col12" >D1</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_3b08ec49_c3d8_11eb_9411_303a64f88675level0_row0" class="row_heading level0 row0" >count</th>
# ...

# %% [markdown]
# ###  <font color='red'><center> Typy danych i zmiana indeksu </center></font>

# %%
dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1361 entries, 0 to 1360
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1361 non-null   object
#  1   A1      1361 non-null   float64
#  2   A2      1361 non-null   float64
#  3   A3      1361 non-null   float64
#  4   R1      1361 non-null   float64
#  5   R2      1361 non-null   float64
#  6   R3      1361 non-null   float64
#  7   M1      1361 non-null   float64
#  8   M2      1361 non-null   float64
#  9   M3      1361 non-null   float64
#  10  P1      1361 non-null   float64
#  11  P2      1361 non-null   float64
#  12  P3      1361 non-null   float64
#  13  D1      1361 non-null   float64
# dtypes: float64(13), object(1)
# memory usage: 149.0+ KB

# %%
# Ważną cechą indeksu jest jego unikalność. Pod jednym adresem powinien być tylko jeden rekord. 
# Sprawdzam czy kolumna 'Date' zawiera unikalne wartości:
dane.Date.is_unique
# Out:
# True

# %%
# Konwertowanie 'Date' z object na datetime
dane['Date'] = pd.to_datetime(dane['Date'])
print(type(dane.Date))
# Out:
# <class 'pandas.core.series.Series'>

# %%
# zmieniam indeks
dane = dane.set_index('Date')
dane.head(3)
# Out:
#                A1     A2     A3     R1     R2     R3     M1     M2     M3  \
# Date
# 1995-01-02  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1995-01-09  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 1995-01-16  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
#
#                P1     P2     P3     D1
# Date
# 1995-01-02  1.272  1.250  1.386  1.104
# 1995-01-09  1.279  1.256  1.387  1.102
# 1995-01-16  1.271  1.249  1.385  1.100

# %% [markdown]
# ###  <font color='red'><center> Dodanie kolumn </center></font>

# %%
dane=pd.DataFrame(dane)

dane['rok']=[dane.index[i].year   for i in range(1361)]
dane['miesiac']=[dane.index[i].month  for i in range(1361)]
dane['dzien']=[dane.index[i].day   for i in range(1361)]
dane['Kiedy']=[dane.index[i]   for i in range(1361)]

dane
# Out:
#                A1     A2     A3     R1     R2     R3     M1     M2     M3  \
# Date
# 1995-01-02  1.127  1.104  1.231  1.079  1.063  1.167  1.170  1.159  1.298
# 1995-01-09  1.134  1.111  1.232  1.086  1.070  1.169  1.177  1.164  1.300
# 1995-01-16  1.126  1.102  1.231  1.078  1.062  1.169  1.168  1.155  1.299
# 1995-01-23  1.132  1.110  1.226  1.083  1.068  1.165  1.177  1.165  1.296
# 1995-01-30  1.131  1.109  1.221  1.083  1.068  1.162  1.176  1.163  1.291
# ...           ...    ...    ...    ...    ...    ...    ...    ...    ...
# 2020-12-28  2.330  2.225  2.535  2.243  2.158  2.423  2.634  2.482  2.858
# 2021-01-04  2.336  2.227  2.549  2.249  2.160  2.437  2.639  2.484  2.867
# 2021-01-11  2.403  2.298  2.610  2.317  2.232  2.498  2.702  2.550  2.927
# 2021-01-18  2.464  2.351  2.688  2.379  2.285  2.579  2.759  2.601  2.995
# 2021-01-25  2.478  2.363  2.703  2.392  2.298  2.593  2.776  2.615  3.014
#
#                P1     P2     P3     D1   rok  miesiac  dzien      Kiedy
# ...

# %%
dane.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1361 entries, 1995-01-02 to 2021-01-25
# Data columns (total 17 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   A1       1361 non-null   float64
#  1   A2       1361 non-null   float64
#  2   A3       1361 non-null   float64
#  3   R1       1361 non-null   float64
#  4   R2       1361 non-null   float64
#  5   R3       1361 non-null   float64
#  6   M1       1361 non-null   float64
#  7   M2       1361 non-null   float64
#  8   M3       1361 non-null   float64
#  9   P1       1361 non-null   float64
#  10  P2       1361 non-null   float64
#  11  P3       1361 non-null   float64
#  12  D1       1361 non-null   float64
#  13  rok      1361 non-null   int64
#  14  miesiac  1361 non-null   int64
#  15  dzien    1361 non-null   int64
#  16  Kiedy    1361 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(13), int64(3)
# memory usage: 191.4 KB

# %% [markdown]
# ###  <font color='red'><center> Wykres 1995-2021r.</center></font>

# %%
#dane.A1.plot()
dane.A1.plot(figsize=(16, 8))

plt.title(label='A1', fontsize=22, color="black")

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("Data", fontsize=15)
plt.ylabel("Cena", fontsize=15)

plt.axhline(y=2.29, color='#e3af34', linestyle='-', linewidth=2) # 2.29 =  średnia dla A1
#plt.axhline(y=3.0, color='red', linestyle='-', linewidth=4)

plt.grid()

# %% [markdown]
# ###  <font color='red'><center> Wykres 2020r. </center></font>

# %%
wykres20 = dane[['A1', 'rok']]
wykres20
# Out:
#                A1   rok
# Date
# 1995-01-02  1.127  1995
# 1995-01-09  1.134  1995
# 1995-01-16  1.126  1995
# 1995-01-23  1.132  1995
# 1995-01-30  1.131  1995
# ...           ...   ...
# 2020-12-28  2.330  2020
# 2021-01-04  2.336  2021
# 2021-01-11  2.403  2021
# 2021-01-18  2.464  2021
# 2021-01-25  2.478  2021
#
# [1361 rows x 2 columns]

# %%
wykres20 = wykres20.loc['2020']
wykres20.head(3)
# Out:
#                A1   rok
# Date
# 2020-01-06  2.665  2020
# 2020-01-13  2.657  2020
# 2020-01-20  2.625  2020

# %%
# 52.14 = 365/7 - zgadza sie (są wszystkie tygodnie z 2020 roku)
wykres20.shape
# Out:
# (52, 2)

# %%
# średnia A1 dla 2020 roku
import statistics

statistics.mean(wykres20.A1)
# Out:
# 2.25825

# %%
#dane.A1.plot()
wykres20.A1.plot(figsize=(16, 8))

plt.title(label='A1 - 2020r.', fontsize=22, color="black")

plt.xticks(fontsize=12)
plt.yticks(fontsize=12)

plt.xlabel("Data", fontsize=15)
plt.ylabel("Cena", fontsize=15)

plt.axhline(y=2.29, color='#e3af34', linestyle='-', linewidth=2) # średnia dla 1995-2021
plt.axhline(y=2.25825, color='red', linestyle='-', linewidth=4) # srednia dla 2020 roku

plt.grid()

# %%
ypoints = wykres20.A1

plt.figure(figsize=(16, 8))

plt.plot( ypoints, 'o:b' , ms=6) # o - symbol, : - linia,  b - blue, ms = rozmiar symbolu

plt.grid()

plt.show()

# %% [markdown]
# ###  <font color='red'><center> 4 Wykresy (można wyświetlać 'dane.A1' albo 'wykres20.A1') </center></font>

# %%
from pandas.plotting import lag_plot
plt.figure(figsize=(16, 8))
lag_plot(wykres20.A1)

# %%
plt.figure(figsize=(16, 8))
wykres20.A1.plot(kind='box')

# %%
plt.figure(figsize=(16, 8))
wykres20.A1.plot(kind='kde')

# %%
from pandas.plotting import autocorrelation_plot
plt.figure(figsize=(16, 8))
autocorrelation_plot(wykres20.A1)

# %% [markdown]
# #  <font color='red'><center> Próbkowanie ziarnistości </center></font>
# - upsampling
# - downsampling

# %%
ZbiorDzienny=wykres20.A1.resample('D').mean()
ZbiorDzienny
# Out:
# Date
# 2020-01-06    2.665
# 2020-01-07      NaN
# 2020-01-08      NaN
# 2020-01-09      NaN
# 2020-01-10      NaN
#               ...
# 2020-12-24      NaN
# 2020-12-25      NaN
# 2020-12-26      NaN
# 2020-12-27      NaN
# 2020-12-28    2.330
# Freq: D, Name: A1, Length: 358, dtype: float64

# %%
ZbiorDzienny.isnull().sum()
# Out:
# 306

# %%
ZbiorDzienny=wykres20.A1.resample('D').mean()
Pelny=ZbiorDzienny.interpolate(method='linear')
plt.figure(figsize=(16, 8))
Pelny.plot()

# %%
ZbiorDzienny=wykres20.A1.resample('D').mean()
Pelny=ZbiorDzienny.interpolate(method='spline',order=2)
plt.figure(figsize=(16, 8))
Pelny.plot()

# %%
ZbiorDzienny=wykres20.A1.resample('Q').mean()
Pelny=ZbiorDzienny.interpolate(method='spline',order=2)
plt.figure(figsize=(16, 8))
Pelny.plot()

# %%
ZbiorDzienny=dane.A1.resample('A').mean()
Pelny=ZbiorDzienny.interpolate(method='spline',order=2)
plt.figure(figsize=(16, 8))
Pelny.plot()
